# %%
import sys
import os

# Get the current working directory
current_dir = os.getcwd()

# Add the project root directory to the Python path
project_root = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.insert(0, project_root)

# Print the project root to verify
print(f"Project root: {project_root}")
# Out:
# Project root: D:\GitHub\price-move-predictor-with-news-sentiment-week1

# %%
# !pip install pandas-ta

# %%
# !pip install yfinance

# %%
from src.stock.analysis import StockAnalysis
from src.stock.visualization import StockVisualization

# Initialize classes
sa = StockAnalysis()
sv = StockVisualization()

# %%
# Example: Load Apple's stock (AAPL)
stock_name = "AAPL" # Change this to the stock you want to analyze
df = sa.load_stock_data(stock_name)

# %%
# Add Moving Averages
df = sa.calculate_moving_averages(df)

# Add Relative Strength Index
df = sa.calculate_rsi(df)

# Add Moving Average Convergence Divergence
df = sa.calculate_macd(df)

# %%
# stock returns
sv.plot_stock_returns(stock_name)

# %%
#plot stock price with moving averages
sv.plot_stock_price(df, stock_name)

# %%
#plot rsi
sv.plot_rsi(df, stock_name)

# %%
# plot macd
sv.plot_macd(df, stock_name)

# %%
# Example: Load Amazon's stock (AMZN)
stock_name = "AMZN"
df = sa.load_stock_data(stock_name)

# Add Moving Averages
df = sa.calculate_moving_averages(df)

# Add Relative Strength Index
df = sa.calculate_rsi(df)

# Add Moving Average Convergence Divergence
df = sa.calculate_macd(df)

# stock returns
sv.plot_stock_returns(stock_name)

#plot stock price with moving averages
sv.plot_stock_price(df, stock_name)

#plot rsi
sv.plot_rsi(df, stock_name)

# plot macd
sv.plot_macd(df, stock_name)

# %%
# Example: Load Google's stock (GOOG)
stock_name = "GOOG"
df = sa.load_stock_data(stock_name)

# Add Moving Averages
df = sa.calculate_moving_averages(df)

# Add Relative Strength Index
df = sa.calculate_rsi(df)

# Add Moving Average Convergence Divergence
df = sa.calculate_macd(df)

# stock returns
sv.plot_stock_returns(stock_name)

#plot stock price with moving averages
sv.plot_stock_price(df, stock_name)

#plot rsi
sv.plot_rsi(df, stock_name)

# plot macd
sv.plot_macd(df, stock_name)

# %%
# Example: Load Meta's stock (META)
stock_name = "META"
df = sa.load_stock_data(stock_name)

# Add Moving Averages
df = sa.calculate_moving_averages(df)

# Add Relative Strength Index
df = sa.calculate_rsi(df)

# Add Moving Average Convergence Divergence
df = sa.calculate_macd(df)

# stock returns
sv.plot_stock_returns(stock_name)

#plot stock price with moving averages
sv.plot_stock_price(df, stock_name)

#plot rsi
sv.plot_rsi(df, stock_name)

# plot macd
sv.plot_macd(df, stock_name)

# %%
# Example: Load Microsoft's stock (MSFT)
stock_name = "MSFT"
df = sa.load_stock_data(stock_name)

# Add Moving Averages
df = sa.calculate_moving_averages(df)

# Add Relative Strength Index
df = sa.calculate_rsi(df)

# Add Moving Average Convergence Divergence
df = sa.calculate_macd(df)

# stock returns
sv.plot_stock_returns(stock_name)

#plot stock price with moving averages
sv.plot_stock_price(df, stock_name)

#plot rsi
sv.plot_rsi(df, stock_name)

# plot macd
sv.plot_macd(df, stock_name)

# %%
# Example: Load NVIDIA's stock (NVDA)
stock_name = "NVDA"
df = sa.load_stock_data(stock_name)

# Add Moving Averages
df = sa.calculate_moving_averages(df)

# Add Relative Strength Index
df = sa.calculate_rsi(df)

# Add Moving Average Convergence Divergence
df = sa.calculate_macd(df)

# stock returns
sv.plot_stock_returns(stock_name)

#plot stock price with moving averages
sv.plot_stock_price(df, stock_name)

#plot rsi
sv.plot_rsi(df, stock_name)

# plot macd
sv.plot_macd(df, stock_name)

# %%
# Example: Load Tesla's stock (TSLA)
stock_name = "TSLA"
df = sa.load_stock_data(stock_name)

# Add Moving Averages
df = sa.calculate_moving_averages(df)

# Add Relative Strength Index
df = sa.calculate_rsi(df)

# Add Moving Average Convergence Divergence
df = sa.calculate_macd(df)

# stock returns
sv.plot_stock_returns(stock_name)

#plot stock price with moving averages
sv.plot_stock_price(df, stock_name)

#plot rsi
sv.plot_rsi(df, stock_name)

# plot macd
sv.plot_macd(df, stock_name)
